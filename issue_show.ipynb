# %%
from pathlib import Path

import PIL
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import torch
from torchvision.datasets import ImageFolder

import normflows as nf

# %% [markdown]
# The dataset is subset of [Places365 Standard dataset](http://places2.csail.mit.edu/download-private.html). Each images was cropped to square and then rescaled to 32x32. It's very small subset, so the training is quick. The point of this notebook is not to train a good model, but to show the problem with values jumping to infinity, during sampling.

# %%
TRAINVAL_DIR = Path('/mnt/arch_data/datasets/inz_small')

# %%
# !tree -d '/mnt/arch_data/datasets/inz_small'
# Out:
# /mnt/arch_data/datasets/inz_small
# ├── forest
# ├── mountains
# └── water
#
# 4 directories

# %%
orig_img_ds = ImageFolder(TRAINVAL_DIR)
print(len(orig_img_ds))
# Out:
# 2135

# %% [markdown]
# # 1) Viewing exemplary images from dataset

# %%
N = 3
for class_name, class_idx in orig_img_ds.class_to_idx.items():
    for i in range(N):
        img, label = orig_img_ds[np.random.randint(0, len(orig_img_ds))]
        while label != class_idx:
            img, label = orig_img_ds[np.random.randint(0, len(orig_img_ds))]
        
        plt.imshow(np.array(img), vmin=0, vmax=255)
        plt.title(f"{class_name} {i+1}/{N}")
        plt.show()

# %% [markdown]
# ### Crating a model
# The below function creates the model. It is identical to the one used in [this notebook](https://github.com/VincentStimper/normalizing-flows/blob/master/examples/glow_colab.ipynb).

# %%
def get_glow_model():
    # Set up model

    # Define flows
    L = 3
    K = 16
    torch.manual_seed(0)

    input_shape = (3, 32, 32)
    n_dims = np.prod(input_shape)
    channels = 3
    hidden_channels = 256
    split_mode = 'channel'
    scale = True
    num_classes = 3

    # Set up flows, distributions and merge operations
    q0 = []
    merges = []
    flows = []
    for i in range(L):
        flows_ = []
        for j in range(K):
            flows_ += [nf.flows.GlowBlock(channels * 2 ** (L + 1 - i), hidden_channels,
                                        split_mode=split_mode, scale=scale)]
        flows_ += [nf.flows.Squeeze()]
        flows += [flows_]
        if i > 0:
            merges += [nf.flows.Merge()]
            latent_shape = (input_shape[0] * 2 ** (L - i), input_shape[1] // 2 ** (L - i), 
                            input_shape[2] // 2 ** (L - i))
        else:
            latent_shape = (input_shape[0] * 2 ** (L + 1), input_shape[1] // 2 ** L, 
                            input_shape[2] // 2 ** L)
        q0 += [nf.distributions.ClassCondDiagGaussian(latent_shape, num_classes)]


    # Construct flow model with the multiscale architecture
    model = nf.MultiscaleFlow(q0, flows, merges)
    return model

# %% [markdown]
# The below function generates an images using the glow model. It works the same as 'sample' method of MultiscaleFlow (see [this file](https://github.com/VincentStimper/normalizing-flows/blob/c6616b1a9f04c0e894b9e045e66bd504db17ef5e/normflows/core.py), line 553  to 586), but it also prints how range of z changes through layers.

# %%
def sample(model: nf.MultiscaleFlow):
    for i in range(len(model.q0)):
        print(f'\n\n\n--------------------------------\ni={i}')
        z_, _ = model.q0[i](1)
        print(f'drawing from q[{i}], z_ range: [{z_.min().item()}, {z_.max().item()}]')

        if i == 0:
            z = z_

        else:
            z, _ = model.merges[i - 1]([z, z_])
            print(f'merging with q, z range: [{z.min().item()}, {z.max().item()}]')

        for j,glow_block in enumerate(model.flows[i][:-1]):
            affine, conv, actnorm = glow_block.flows
            part_length = len(model.flows[i])
            #----------------------------------------------------------------

            splt, aff, mrg = affine.flows

            [z1, z2], _ = splt(z)

            print(f'{aff.scale_map=}')
            param = aff.param_map(z1)
            shift = param[:, 0::2, ...]
            scale_ = param[:, 1::2, ...]
            print(f'j {j+1}/{part_length}, scale max and min: '
                  f'{scale_.min().item()}, {scale_.max().item()}')
            scale = torch.sigmoid(scale_ + 2)
            z2 = z2 / scale + shift

            z, _ = mrg([z1,z2])

            print(f'j {j+1}/{part_length}, after affine, '
                  f'z range: [{z.min().item()}, {z.max().item()}], {z.shape=}')

            #----------------------------------------------------------------
            z, _ = conv(z)
            print(f'j {j+1}/{part_length}, after conv, '
                  f'z range: [{z.min().item()}, {z.max().item()}], {z.shape=}')
            #----------------------------------------------------------------
            z, _ = actnorm(z)
            print(f'j {j+1}/{part_length}, after actnorm, '
                  f'z range: [{z.min().item()}, {z.max().item()}], {z.shape=}')
            #----------------------------------------------------------------
        
        z, _ = model.flows[i][-1](z) # the squeeze operation

    return z

# %%
enable_cuda = True
device = torch.device('cuda' if torch.cuda.is_available() and enable_cuda else 'cpu')
print(f'Using device {device}')
# Out:
# Using device cuda

# %% [markdown]
# ## 1) without training
# ### 1.1) sampling

# %%
model1 = get_glow_model()
model1 = model1.to(device)
with torch.no_grad():
    img = sample(model1)
# Out:
# /home/jedrzej/miniconda3/envs/normflows/lib/python3.11/site-packages/torch/_tensor.py:791: UserWarning: torch.lu is deprecated in favor of torch.linalg.lu_factor / torch.linalg.lu_factor_ex and will be removed in a future PyTorch release.
# LU, pivots = torch.lu(A, compute_pivots)
# should be replaced with
# LU, pivots = torch.linalg.lu_factor(A, compute_pivots)
# and
# LU, pivots, info = torch.lu(A, compute_pivots, get_infos=True)
# should be replaced with
# LU, pivots, info = torch.linalg.lu_factor_ex(A, compute_pivots) (Triggered internally at /opt/conda/conda-bld/pytorch_1724789121465/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:1984.)
#   LU, pivots, infos = torch._lu_with_info(
# --------------------------------
# i=0
# drawing from q[0], z_ range: [-2.994307279586792, 3.026895761489868]
# aff.scale_map='sigmoid'
# j 1/17, scale max and min: 0.0, 0.0
# j 1/17, after affine, z range: [-3.2699389457702637, 3.0546576976776123], z.shape=torch.Size([1, 48, 4, 4])
# j 1/17, after conv, z range: [-3.310488700866699, 3.0825400352478027], z.shape=torch.Size([1, 48, 4, 4])
# j 1/17, after actnorm, z range: [-2.5457897186279297, 2.5549004077911377], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 2/17, scale max and min: 0.0, 0.0
# j 2/17, after affine, z range: [-2.825551748275757, 2.6080377101898193], z.shape=torch.Size([1, 48, 4, 4])
# j 2/17, after conv, z range: [-2.731783628463745, 3.2588372230529785], z.shape=torch.Size([1, 48, 4, 4])
# j 2/17, after actnorm, z range: [-2.5582633018493652, 2.6027348041534424], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 3/17, scale max and min: 0.0, 0.0
# j 3/17, after affine, z range: [-2.6760334968566895, 2.954976797103882], z.shape=torch.Size([1, 48, 4, 4])
# j 3/17, after conv, z range: [-2.937706232070923, 3.019015312194824], z.shape=torch.Size([1, 48, 4, 4])
# j 3/17, after actnorm, z range: [-2.8212156295776367, 2.8978841304779053], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 4/17, scale max and min: 0.0, 0.0
# j 4/17, after affine, z range: [-3.2030258178710938, 2.8978841304779053], z.shape=torch.Size([1, 48, 4, 4])
# j 4/17, after conv, z range: [-2.952911853790283, 3.0135676860809326], z.shape=torch.Size([1, 48, 4, 4])
# j 4/17, after actnorm, z range: [-2.609259605407715, 2.866943836212158], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 5/17, scale max and min: 0.0, 0.0
# j 5/17, after affine, z range: [-2.9623847007751465, 2.866943836212158], z.shape=torch.Size([1, 48, 4, 4])
# j 5/17, after conv, z range: [-3.562645673751831, 3.844998836517334], z.shape=torch.Size([1, 48, 4, 4])
# j 5/17, after actnorm, z range: [-2.6867895126342773, 3.0839078426361084], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 6/17, scale max and min: 0.0, 0.0
# j 6/17, after affine, z range: [-2.6867895126342773, 3.501269578933716], z.shape=torch.Size([1, 48, 4, 4])
# j 6/17, after conv, z range: [-2.8016934394836426, 3.068770408630371], z.shape=torch.Size([1, 48, 4, 4])
# j 6/17, after actnorm, z range: [-2.5505096912384033, 2.8593666553497314], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 7/17, scale max and min: 0.0, 0.0
# j 7/17, after affine, z range: [-2.5698323249816895, 2.8803091049194336], z.shape=torch.Size([1, 48, 4, 4])
# j 7/17, after conv, z range: [-3.142413377761841, 3.2141852378845215], z.shape=torch.Size([1, 48, 4, 4])
# j 7/17, after actnorm, z range: [-2.7640016078948975, 2.6126532554626465], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 8/17, scale max and min: 0.0, 0.0
# j 8/17, after affine, z range: [-2.851351499557495, 2.9662375450134277], z.shape=torch.Size([1, 48, 4, 4])
# j 8/17, after conv, z range: [-2.9948620796203613, 3.5075843334198], z.shape=torch.Size([1, 48, 4, 4])
# j 8/17, after actnorm, z range: [-2.6304662227630615, 2.6399178504943848], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 9/17, scale max and min: 0.0, 0.0
# j 9/17, after affine, z range: [-2.9864611625671387, 2.6702475547790527], z.shape=torch.Size([1, 48, 4, 4])
# j 9/17, after conv, z range: [-3.913088321685791, 2.6526856422424316], z.shape=torch.Size([1, 48, 4, 4])
# j 9/17, after actnorm, z range: [-2.5765225887298584, 2.571336269378662], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 10/17, scale max and min: 0.0, 0.0
# j 10/17, after affine, z range: [-2.8653385639190674, 2.9193289279937744], z.shape=torch.Size([1, 48, 4, 4])
# j 10/17, after conv, z range: [-2.69555401802063, 3.061723232269287], z.shape=torch.Size([1, 48, 4, 4])
# j 10/17, after actnorm, z range: [-2.663423538208008, 2.580036163330078], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 11/17, scale max and min: 0.0, 0.0
# j 11/17, after affine, z range: [-3.023878812789917, 2.580036163330078], z.shape=torch.Size([1, 48, 4, 4])
# j 11/17, after conv, z range: [-3.0054361820220947, 2.7010347843170166], z.shape=torch.Size([1, 48, 4, 4])
# j 11/17, after actnorm, z range: [-2.7995455265045166, 2.7645225524902344], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 12/17, scale max and min: 0.0, 0.0
# j 12/17, after affine, z range: [-2.7995455265045166, 2.7645225524902344], z.shape=torch.Size([1, 48, 4, 4])
# j 12/17, after conv, z range: [-3.0527381896972656, 3.4773168563842773], z.shape=torch.Size([1, 48, 4, 4])
# j 12/17, after actnorm, z range: [-2.5506155490875244, 2.721978187561035], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 13/17, scale max and min: 0.0, 0.0
# j 13/17, after affine, z range: [-2.680680274963379, 3.090358018875122], z.shape=torch.Size([1, 48, 4, 4])
# j 13/17, after conv, z range: [-2.831598997116089, 3.204669952392578], z.shape=torch.Size([1, 48, 4, 4])
# j 13/17, after actnorm, z range: [-2.7784976959228516, 2.673269748687744], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 14/17, scale max and min: 0.0, 0.0
# j 14/17, after affine, z range: [-3.154526710510254, 3.035057544708252], z.shape=torch.Size([1, 48, 4, 4])
# j 14/17, after conv, z range: [-3.4978137016296387, 2.6631367206573486], z.shape=torch.Size([1, 48, 4, 4])
# j 14/17, after actnorm, z range: [-2.893763542175293, 2.558107852935791], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 15/17, scale max and min: 0.0, 0.0
# j 15/17, after affine, z range: [-3.2853920459747314, 2.839226484298706], z.shape=torch.Size([1, 48, 4, 4])
# j 15/17, after conv, z range: [-3.3279953002929688, 3.2768194675445557], z.shape=torch.Size([1, 48, 4, 4])
# j 15/17, after actnorm, z range: [-2.6443819999694824, 2.9184467792510986], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 16/17, scale max and min: 0.0, 0.0
# j 16/17, after affine, z range: [-2.6487863063812256, 2.9184467792510986], z.shape=torch.Size([1, 48, 4, 4])
# j 16/17, after conv, z range: [-3.6183059215545654, 3.0817644596099854], z.shape=torch.Size([1, 48, 4, 4])
# j 16/17, after actnorm, z range: [-2.603560209274292, 2.473560094833374], z.shape=torch.Size([1, 48, 4, 4])
#
#
#
# --------------------------------
# i=1
# drawing from q[1], z_ range: [-3.8595376014709473, 3.525210380554199]
# merging with q, z range: [-3.8595376014709473, 3.525210380554199]
# aff.scale_map='sigmoid'
# j 1/17, scale max and min: 0.0, 0.0
# j 1/17, after affine, z range: [-4.381869316101074, 4.002295970916748], z.shape=torch.Size([1, 24, 8, 8])
# j 1/17, after conv, z range: [-3.638258457183838, 3.807234525680542], z.shape=torch.Size([1, 24, 8, 8])
# j 1/17, after actnorm, z range: [-3.353494882583618, 3.300755500793457], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 2/17, scale max and min: 0.0, 0.0
# j 2/17, after affine, z range: [-3.392086982727051, 3.747464418411255], z.shape=torch.Size([1, 24, 8, 8])
# j 2/17, after conv, z range: [-3.197615623474121, 3.261152505874634], z.shape=torch.Size([1, 24, 8, 8])
# j 2/17, after actnorm, z range: [-3.055586338043213, 2.968010425567627], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 3/17, scale max and min: 0.0, 0.0
# j 3/17, after affine, z range: [-3.4691152572631836, 3.3402793407440186], z.shape=torch.Size([1, 24, 8, 8])
# j 3/17, after conv, z range: [-3.4622602462768555, 4.04279088973999], z.shape=torch.Size([1, 24, 8, 8])
# j 3/17, after actnorm, z range: [-3.4528965950012207, 3.4465978145599365], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 4/17, scale max and min: 0.0, 0.0
# j 4/17, after affine, z range: [-3.9201955795288086, 3.9130442142486572], z.shape=torch.Size([1, 24, 8, 8])
# j 4/17, after conv, z range: [-3.5153725147247314, 3.7894153594970703], z.shape=torch.Size([1, 24, 8, 8])
# j 4/17, after actnorm, z range: [-3.1857516765594482, 3.381727933883667], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 5/17, scale max and min: 0.0, 0.0
# j 5/17, after affine, z range: [-3.1965456008911133, 3.83939528465271], z.shape=torch.Size([1, 24, 8, 8])
# j 5/17, after conv, z range: [-3.5717062950134277, 3.8989200592041016], z.shape=torch.Size([1, 24, 8, 8])
# j 5/17, after actnorm, z range: [-2.9969022274017334, 3.5294418334960938], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 6/17, scale max and min: 0.0, 0.0
# j 6/17, after affine, z range: [-3.402488946914673, 4.0071001052856445], z.shape=torch.Size([1, 24, 8, 8])
# j 6/17, after conv, z range: [-3.834146738052368, 3.2361412048339844], z.shape=torch.Size([1, 24, 8, 8])
# j 6/17, after actnorm, z range: [-3.335522413253784, 2.8724796772003174], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 7/17, scale max and min: 0.0, 0.0
# j 7/17, after affine, z range: [-3.7869365215301514, 3.261227607727051], z.shape=torch.Size([1, 24, 8, 8])
# j 7/17, after conv, z range: [-3.0979020595550537, 3.7073373794555664], z.shape=torch.Size([1, 24, 8, 8])
# j 7/17, after actnorm, z range: [-2.8637492656707764, 3.3210604190826416], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 8/17, scale max and min: 0.0, 0.0
# j 8/17, after affine, z range: [-3.2513158321380615, 3.770517349243164], z.shape=torch.Size([1, 24, 8, 8])
# j 8/17, after conv, z range: [-4.026459693908691, 3.2427890300750732], z.shape=torch.Size([1, 24, 8, 8])
# j 8/17, after actnorm, z range: [-3.9003963470458984, 2.921776533126831], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 9/17, scale max and min: 0.0, 0.0
# j 9/17, after affine, z range: [-4.428257942199707, 3.3171961307525635], z.shape=torch.Size([1, 24, 8, 8])
# j 9/17, after conv, z range: [-3.0892550945281982, 3.797738552093506], z.shape=torch.Size([1, 24, 8, 8])
# j 9/17, after actnorm, z range: [-2.838974714279175, 3.265747547149658], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 10/17, scale max and min: 0.0, 0.0
# j 10/17, after affine, z range: [-3.0206058025360107, 3.70771861076355], z.shape=torch.Size([1, 24, 8, 8])
# j 10/17, after conv, z range: [-3.3291244506835938, 3.8338115215301514], z.shape=torch.Size([1, 24, 8, 8])
# j 10/17, after actnorm, z range: [-3.0817246437072754, 3.5309524536132812], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 11/17, scale max and min: 0.0, 0.0
# j 11/17, after affine, z range: [-3.498790979385376, 4.008815288543701], z.shape=torch.Size([1, 24, 8, 8])
# j 11/17, after conv, z range: [-3.7317047119140625, 3.735391855239868], z.shape=torch.Size([1, 24, 8, 8])
# j 11/17, after actnorm, z range: [-3.1459856033325195, 3.43851375579834], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 12/17, scale max and min: 0.0, 0.0
# j 12/17, after affine, z range: [-3.571748733520508, 3.9038662910461426], z.shape=torch.Size([1, 24, 8, 8])
# j 12/17, after conv, z range: [-3.5187649726867676, 3.3724756240844727], z.shape=torch.Size([1, 24, 8, 8])
# j 12/17, after actnorm, z range: [-3.193282127380371, 2.986252546310425], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 13/17, scale max and min: 0.0, 0.0
# j 13/17, after affine, z range: [-3.5271761417388916, 3.3903980255126953], z.shape=torch.Size([1, 24, 8, 8])
# j 13/17, after conv, z range: [-4.036280155181885, 3.632939577102661], z.shape=torch.Size([1, 24, 8, 8])
# j 13/17, after actnorm, z range: [-3.357192039489746, 3.0950026512145996], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 14/17, scale max and min: 0.0, 0.0
# j 14/17, after affine, z range: [-3.5665476322174072, 3.139052629470825], z.shape=torch.Size([1, 24, 8, 8])
# j 14/17, after conv, z range: [-3.6002156734466553, 3.5846657752990723], z.shape=torch.Size([1, 24, 8, 8])
# j 14/17, after actnorm, z range: [-3.21756649017334, 3.238041639328003], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 15/17, scale max and min: 0.0, 0.0
# j 15/17, after affine, z range: [-3.3322372436523438, 3.6762630939483643], z.shape=torch.Size([1, 24, 8, 8])
# j 15/17, after conv, z range: [-4.2157793045043945, 3.0610885620117188], z.shape=torch.Size([1, 24, 8, 8])
# j 15/17, after actnorm, z range: [-3.496558904647827, 2.907886028289795], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 16/17, scale max and min: 0.0, 0.0
# j 16/17, after affine, z range: [-3.511110544204712, 3.3014256954193115], z.shape=torch.Size([1, 24, 8, 8])
# j 16/17, after conv, z range: [-3.482290506362915, 3.1285057067871094], z.shape=torch.Size([1, 24, 8, 8])
# j 16/17, after actnorm, z range: [-3.1480424404144287, 2.8497984409332275], z.shape=torch.Size([1, 24, 8, 8])
#
#
#
# --------------------------------
# i=2
# drawing from q[2], z_ range: [-3.09142804145813, 2.9140591621398926]
# merging with q, z range: [-3.1480424404144287, 2.9140591621398926]
# aff.scale_map='sigmoid'
# j 1/17, scale max and min: 0.0, 0.0
# j 1/17, after affine, z range: [-3.509807586669922, 3.30843448638916], z.shape=torch.Size([1, 12, 16, 16])
# j 1/17, after conv, z range: [-3.56668758392334, 3.6709165573120117], z.shape=torch.Size([1, 12, 16, 16])
# j 1/17, after actnorm, z range: [-3.2685916423797607, 3.321784496307373], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 2/17, scale max and min: 0.0, 0.0
# j 2/17, after affine, z range: [-3.559833526611328, 3.379645586013794], z.shape=torch.Size([1, 12, 16, 16])
# j 2/17, after conv, z range: [-3.2553699016571045, 3.614008665084839], z.shape=torch.Size([1, 12, 16, 16])
# j 2/17, after actnorm, z range: [-3.3775811195373535, 3.3178043365478516], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 3/17, scale max and min: 0.0, 0.0
# j 3/17, after affine, z range: [-3.8346872329711914, 3.5468552112579346], z.shape=torch.Size([1, 12, 16, 16])
# j 3/17, after conv, z range: [-3.3185746669769287, 3.818732976913452], z.shape=torch.Size([1, 12, 16, 16])
# j 3/17, after actnorm, z range: [-3.1933023929595947, 3.689959764480591], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 4/17, scale max and min: 0.0, 0.0
# j 4/17, after affine, z range: [-3.6254689693450928, 3.689959764480591], z.shape=torch.Size([1, 12, 16, 16])
# j 4/17, after conv, z range: [-3.5614359378814697, 3.965733289718628], z.shape=torch.Size([1, 12, 16, 16])
# j 4/17, after actnorm, z range: [-3.459773063659668, 3.4767959117889404], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 5/17, scale max and min: 0.0, 0.0
# j 5/17, after affine, z range: [-3.7548036575317383, 3.4767959117889404], z.shape=torch.Size([1, 12, 16, 16])
# j 5/17, after conv, z range: [-3.6002213954925537, 4.480668544769287], z.shape=torch.Size([1, 12, 16, 16])
# j 5/17, after actnorm, z range: [-3.5054280757904053, 4.3626933097839355], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 6/17, scale max and min: 0.0, 0.0
# j 6/17, after affine, z range: [-3.9798364639282227, 4.95311975479126], z.shape=torch.Size([1, 12, 16, 16])
# j 6/17, after conv, z range: [-3.7164788246154785, 4.800549507141113], z.shape=torch.Size([1, 12, 16, 16])
# j 6/17, after actnorm, z range: [-3.354713201522827, 4.64321231842041], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 7/17, scale max and min: 0.0, 0.0
# j 7/17, after affine, z range: [-3.8087244033813477, 5.271603107452393], z.shape=torch.Size([1, 12, 16, 16])
# j 7/17, after conv, z range: [-3.815915107727051, 3.6935503482818604], z.shape=torch.Size([1, 12, 16, 16])
# j 7/17, after actnorm, z range: [-3.6220061779022217, 3.2772159576416016], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 8/17, scale max and min: 0.0, 0.0
# j 8/17, after affine, z range: [-3.761532783508301, 3.716557502746582], z.shape=torch.Size([1, 12, 16, 16])
# j 8/17, after conv, z range: [-4.203823089599609, 3.849090576171875], z.shape=torch.Size([1, 12, 16, 16])
# j 8/17, after actnorm, z range: [-3.607245683670044, 3.603487253189087], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 9/17, scale max and min: 0.0, 0.0
# j 9/17, after affine, z range: [-3.607245683670044, 3.780541181564331], z.shape=torch.Size([1, 12, 16, 16])
# j 9/17, after conv, z range: [-3.3270983695983887, 3.890390396118164], z.shape=torch.Size([1, 12, 16, 16])
# j 9/17, after actnorm, z range: [-3.1297214031219482, 3.7772793769836426], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 10/17, scale max and min: 0.0, 0.0
# j 10/17, after affine, z range: [-3.553283452987671, 3.8397133350372314], z.shape=torch.Size([1, 12, 16, 16])
# j 10/17, after conv, z range: [-3.9002022743225098, 4.3881940841674805], z.shape=torch.Size([1, 12, 16, 16])
# j 10/17, after actnorm, z range: [-3.397578716278076, 3.6527352333068848], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 11/17, scale max and min: 0.0, 0.0
# j 11/17, after affine, z range: [-3.397578716278076, 4.10917329788208], z.shape=torch.Size([1, 12, 16, 16])
# j 11/17, after conv, z range: [-3.981785535812378, 3.656705379486084], z.shape=torch.Size([1, 12, 16, 16])
# j 11/17, after actnorm, z range: [-3.542045831680298, 3.462190628051758], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 12/17, scale max and min: 0.0, 0.0
# j 12/17, after affine, z range: [-3.542045831680298, 3.9307475090026855], z.shape=torch.Size([1, 12, 16, 16])
# j 12/17, after conv, z range: [-3.807704448699951, 3.7929017543792725], z.shape=torch.Size([1, 12, 16, 16])
# j 12/17, after actnorm, z range: [-3.5088133811950684, 3.3720521926879883], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 13/17, scale max and min: 0.0, 0.0
# j 13/17, after affine, z range: [-3.884523630142212, 3.462315797805786], z.shape=torch.Size([1, 12, 16, 16])
# j 13/17, after conv, z range: [-4.591592788696289, 3.687382221221924], z.shape=torch.Size([1, 12, 16, 16])
# j 13/17, after actnorm, z range: [-3.924342155456543, 3.3062734603881836], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 14/17, scale max and min: 0.0, 0.0
# j 14/17, after affine, z range: [-4.4554443359375, 3.7537291049957275], z.shape=torch.Size([1, 12, 16, 16])
# j 14/17, after conv, z range: [-4.102773666381836, 3.656827926635742], z.shape=torch.Size([1, 12, 16, 16])
# j 14/17, after actnorm, z range: [-3.380659580230713, 3.2760071754455566], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 15/17, scale max and min: 0.0, 0.0
# j 15/17, after affine, z range: [-3.4688851833343506, 3.6172902584075928], z.shape=torch.Size([1, 12, 16, 16])
# j 15/17, after conv, z range: [-3.938675880432129, 3.5312578678131104], z.shape=torch.Size([1, 12, 16, 16])
# j 15/17, after actnorm, z range: [-3.499157667160034, 3.520052671432495], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 16/17, scale max and min: 0.0, 0.0
# j 16/17, after affine, z range: [-3.97271728515625, 3.520052671432495], z.shape=torch.Size([1, 12, 16, 16])
# j 16/17, after conv, z range: [-3.8458664417266846, 3.809911012649536], z.shape=torch.Size([1, 12, 16, 16])
# j 16/17, after actnorm, z range: [-3.4603097438812256, 3.454265594482422], z.shape=torch.Size([1, 12, 16, 16])

# %% [markdown]
# Without any training, sampling works as it should. Values of z don't go to infinity.

# %%
img = img.cpu().numpy()
img = np.transpose(img[0], (1,2,0))
plt.imshow(img, vmin=0.0, vmax=1.0)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-3.4603097..3.4542656].

# %% [markdown]
# As you could expect, the generated image is just random noise.

# %% [markdown]
# ### 1.1) converting

# %%
img = orig_img_ds[np.random.randint(0, len(orig_img_ds))][0]

plt.imshow(img)
plt.show()

img = np.transpose(np.array(img), (2,0,1))
img = img.astype(np.float32) / 255.0
img = np.reshape(img, (1, 3, 32, 32))

with torch.no_grad():
    z, _ = model1.inverse_and_log_det(torch.tensor(img).to(device))
    res_img, _ = model1.forward_and_log_det(z)
    res_img = res_img.cpu().numpy()

print('max diff is : ', np.abs(res_img - img).max())
plt.imshow(np.transpose(res_img[0], (1,2,0)), vmin=0.0, vmax=1.0)
plt.show()
# Out:
# max diff is :  2.861023e-06

# %% [markdown]
# Converting image to latent space and back also works.

# %% [markdown]
# # 2) training on 0.0 - 1.0 RGB

# %%
def pil_to_rgb_tensor(img: PIL.Image) -> np.ndarray:
    img = np.transpose(np.array(img), (2,0,1))
    img = img.astype(np.float32) + np.random.rand(*img.shape).astype(np.float32)
    img /= 256.0
    return torch.tensor(img)

# %%
dataset = ImageFolder(TRAINVAL_DIR, transform=pil_to_rgb_tensor)
img = dataset[np.random.randint(0, len(dataset))][0]
img.min().item(), img.max().item()
# Out:
# (0.046736616641283035, 0.8739328384399414)

# %% [markdown]
# Normally there whould be train and validation datasets, but the point of this notebook is not to train a good model, but to show the problem with infinity, during sampling. To make training fast, I train only for 4 epochs on very small dataset.

# %%
train_loader = torch.utils.data.DataLoader(dataset, batch_size=8, shuffle=True)

model2 = get_glow_model()
model2 = model2.to(device)
optimizer = torch.optim.Adamax(model2.parameters(), lr=1e-3, weight_decay=1e-5)

EPOCH = 4
loss_hist = []

for epoch in range(EPOCH):
    print(f'epoch {epoch+1} /{EPOCH}')
    for x,y in tqdm(train_loader):
        optimizer.zero_grad()
        loss = model2.forward_kld(x.to(device), y.to(device))
        if torch.isnan(loss) or torch.isinf(loss):
            print(f'loss is bad: {loss}')
            break
        else:
            loss.backward()
            optimizer.step()
        loss_hist = np.append(loss_hist, loss.detach().to('cpu').numpy())
# Out:
# epoch 1 /4
# 100%|██████████| 267/267 [00:17<00:00, 15.59it/s]
# epoch 2 /4
# 100%|██████████| 267/267 [00:17<00:00, 15.57it/s]
# epoch 3 /4
# 100%|██████████| 267/267 [00:17<00:00, 15.17it/s]
# epoch 4 /4
# 100%|██████████| 267/267 [00:17<00:00, 14.98it/s]

# %%
plt.plot(loss_hist)
plt.show()

# %% [markdown]
# ### 2.1) Sampling

# %%
with torch.no_grad():
    img = sample(model2)
# Out:
# --------------------------------
# i=0
# drawing from q[0], z_ range: [-3.0099775791168213, 3.0110137462615967]
# aff.scale_map='sigmoid'
# j 1/17, scale max and min: -0.7412835359573364, 1.7748216390609741
# j 1/17, after affine, z range: [-3.371428966522217, 3.0110137462615967], z.shape=torch.Size([1, 48, 4, 4])
# j 1/17, after conv, z range: [-3.1457440853118896, 3.0786020755767822], z.shape=torch.Size([1, 48, 4, 4])
# j 1/17, after actnorm, z range: [-3.2763822078704834, 3.208299398422241], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 2/17, scale max and min: -0.7888070940971375, 1.6599103212356567
# j 2/17, after affine, z range: [-3.541261911392212, 3.689807891845703], z.shape=torch.Size([1, 48, 4, 4])
# j 2/17, after conv, z range: [-2.8487753868103027, 3.1166486740112305], z.shape=torch.Size([1, 48, 4, 4])
# j 2/17, after actnorm, z range: [-2.657766342163086, 2.94789719581604], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 3/17, scale max and min: -0.8098106980323792, 1.269195556640625
# j 3/17, after affine, z range: [-3.1420233249664307, 3.171952962875366], z.shape=torch.Size([1, 48, 4, 4])
# j 3/17, after conv, z range: [-3.234218120574951, 3.3930068016052246], z.shape=torch.Size([1, 48, 4, 4])
# j 3/17, after actnorm, z range: [-3.0038585662841797, 3.581289529800415], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 4/17, scale max and min: -0.8654434084892273, 3.4667437076568604
# j 4/17, after affine, z range: [-3.685546636581421, 3.581289529800415], z.shape=torch.Size([1, 48, 4, 4])
# j 4/17, after conv, z range: [-3.3260929584503174, 3.176051616668701], z.shape=torch.Size([1, 48, 4, 4])
# j 4/17, after actnorm, z range: [-3.1206586360931396, 3.2234604358673096], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 5/17, scale max and min: -0.8414065837860107, 1.1106404066085815
# j 5/17, after affine, z range: [-3.346728801727295, 3.6989426612854004], z.shape=torch.Size([1, 48, 4, 4])
# j 5/17, after conv, z range: [-3.6948742866516113, 4.454116344451904], z.shape=torch.Size([1, 48, 4, 4])
# j 5/17, after actnorm, z range: [-3.5611472129821777, 3.8219783306121826], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 6/17, scale max and min: -0.4817180633544922, 2.6517341136932373
# j 6/17, after affine, z range: [-3.5611472129821777, 4.123075008392334], z.shape=torch.Size([1, 48, 4, 4])
# j 6/17, after conv, z range: [-3.732328414916992, 3.8476388454437256], z.shape=torch.Size([1, 48, 4, 4])
# j 6/17, after actnorm, z range: [-3.4583089351654053, 3.980024576187134], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 7/17, scale max and min: -0.4811413288116455, 2.5974314212799072
# j 7/17, after affine, z range: [-4.094965934753418, 3.980024576187134], z.shape=torch.Size([1, 48, 4, 4])
# j 7/17, after conv, z range: [-3.4900479316711426, 3.3846137523651123], z.shape=torch.Size([1, 48, 4, 4])
# j 7/17, after actnorm, z range: [-3.4174375534057617, 3.2852957248687744], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 8/17, scale max and min: -0.46080270409584045, 0.8002827763557434
# j 8/17, after affine, z range: [-3.687314033508301, 3.524440050125122], z.shape=torch.Size([1, 48, 4, 4])
# j 8/17, after conv, z range: [-3.8655190467834473, 3.6309690475463867], z.shape=torch.Size([1, 48, 4, 4])
# j 8/17, after actnorm, z range: [-4.09058952331543, 3.257824182510376], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 9/17, scale max and min: -0.6278653740882874, 2.0989041328430176
# j 9/17, after affine, z range: [-4.09058952331543, 3.572436809539795], z.shape=torch.Size([1, 48, 4, 4])
# j 9/17, after conv, z range: [-4.665201187133789, 3.7726736068725586], z.shape=torch.Size([1, 48, 4, 4])
# j 9/17, after actnorm, z range: [-4.157959461212158, 3.4451985359191895], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 10/17, scale max and min: -0.6454633474349976, 0.2511487901210785
# j 10/17, after affine, z range: [-4.962493896484375, 3.4451985359191895], z.shape=torch.Size([1, 48, 4, 4])
# j 10/17, after conv, z range: [-5.318447113037109, 3.2487058639526367], z.shape=torch.Size([1, 48, 4, 4])
# j 10/17, after actnorm, z range: [-4.844534873962402, 3.101736068725586], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 11/17, scale max and min: -0.5336045622825623, 2.504058361053467
# j 11/17, after affine, z range: [-4.844534873962402, 3.482002019882202], z.shape=torch.Size([1, 48, 4, 4])
# j 11/17, after conv, z range: [-4.712165832519531, 3.4478490352630615], z.shape=torch.Size([1, 48, 4, 4])
# j 11/17, after actnorm, z range: [-4.555321216583252, 3.456169605255127], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 12/17, scale max and min: -0.5992080569267273, 1.3382606506347656
# j 12/17, after affine, z range: [-5.007262229919434, 3.5638089179992676], z.shape=torch.Size([1, 48, 4, 4])
# j 12/17, after conv, z range: [-3.842275619506836, 4.201406478881836], z.shape=torch.Size([1, 48, 4, 4])
# j 12/17, after actnorm, z range: [-3.960169792175293, 3.83414888381958], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 13/17, scale max and min: -0.5370245575904846, 1.406917929649353
# j 13/17, after affine, z range: [-4.363962650299072, 3.83414888381958], z.shape=torch.Size([1, 48, 4, 4])
# j 13/17, after conv, z range: [-3.656578302383423, 3.8471832275390625], z.shape=torch.Size([1, 48, 4, 4])
# j 13/17, after actnorm, z range: [-3.978543758392334, 3.4509117603302], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 14/17, scale max and min: -0.7099085450172424, 1.5654836893081665
# j 14/17, after affine, z range: [-3.978543758392334, 3.4509117603302], z.shape=torch.Size([1, 48, 4, 4])
# j 14/17, after conv, z range: [-5.337215423583984, 3.3843812942504883], z.shape=torch.Size([1, 48, 4, 4])
# j 14/17, after actnorm, z range: [-4.035325050354004, 3.4531877040863037], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 15/17, scale max and min: -0.4033389985561371, 2.415811538696289
# j 15/17, after affine, z range: [-4.353923320770264, 3.7369532585144043], z.shape=torch.Size([1, 48, 4, 4])
# j 15/17, after conv, z range: [-4.1370625495910645, 3.813854455947876], z.shape=torch.Size([1, 48, 4, 4])
# j 15/17, after actnorm, z range: [-3.323916435241699, 3.9155385494232178], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 16/17, scale max and min: -0.5478159189224243, 1.140261173248291
# j 16/17, after affine, z range: [-3.323916435241699, 3.9155385494232178], z.shape=torch.Size([1, 48, 4, 4])
# j 16/17, after conv, z range: [-3.8293118476867676, 5.074953556060791], z.shape=torch.Size([1, 48, 4, 4])
# j 16/17, after actnorm, z range: [-3.9996631145477295, 4.355010032653809], z.shape=torch.Size([1, 48, 4, 4])
#
#
#
# --------------------------------
# i=1
# drawing from q[1], z_ range: [-3.813347101211548, 3.5441930294036865]
# merging with q, z range: [-3.9996631145477295, 4.355010032653809]
# aff.scale_map='sigmoid'
# j 1/17, scale max and min: -1.4805716276168823, 1.4756029844284058
# j 1/17, after affine, z range: [-4.75035285949707, 4.355010032653809], z.shape=torch.Size([1, 24, 8, 8])
# j 1/17, after conv, z range: [-4.353455543518066, 4.188671112060547], z.shape=torch.Size([1, 24, 8, 8])
# j 1/17, after actnorm, z range: [-5.02986478805542, 4.350448131561279], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 2/17, scale max and min: -1.404907464981079, 1.1275304555892944
# j 2/17, after affine, z range: [-5.02986478805542, 4.350448131561279], z.shape=torch.Size([1, 24, 8, 8])
# j 2/17, after conv, z range: [-4.039216041564941, 4.961618900299072], z.shape=torch.Size([1, 24, 8, 8])
# j 2/17, after actnorm, z range: [-4.318796157836914, 4.419422149658203], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 3/17, scale max and min: -1.8794089555740356, 0.28166404366493225
# j 3/17, after affine, z range: [-5.602775573730469, 4.604357719421387], z.shape=torch.Size([1, 24, 8, 8])
# j 3/17, after conv, z range: [-4.972543716430664, 4.8532843589782715], z.shape=torch.Size([1, 24, 8, 8])
# j 3/17, after actnorm, z range: [-4.746734619140625, 4.667991638183594], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 4/17, scale max and min: -1.052847981452942, 0.7381472587585449
# j 4/17, after affine, z range: [-4.81947660446167, 5.4240617752075195], z.shape=torch.Size([1, 24, 8, 8])
# j 4/17, after conv, z range: [-4.329143047332764, 5.235639572143555], z.shape=torch.Size([1, 24, 8, 8])
# j 4/17, after actnorm, z range: [-4.0977396965026855, 4.65369987487793], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 5/17, scale max and min: -1.7133479118347168, 1.2436832189559937
# j 5/17, after affine, z range: [-4.427586555480957, 5.4661641120910645], z.shape=torch.Size([1, 24, 8, 8])
# j 5/17, after conv, z range: [-4.144240856170654, 4.831578254699707], z.shape=torch.Size([1, 24, 8, 8])
# j 5/17, after actnorm, z range: [-4.027677059173584, 4.688233852386475], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 6/17, scale max and min: -1.8614567518234253, 2.532594919204712
# j 6/17, after affine, z range: [-4.781196594238281, 4.688233852386475], z.shape=torch.Size([1, 24, 8, 8])
# j 6/17, after conv, z range: [-6.6037211418151855, 5.081187725067139], z.shape=torch.Size([1, 24, 8, 8])
# j 6/17, after actnorm, z range: [-6.49763298034668, 5.00660514831543], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 7/17, scale max and min: -1.0006418228149414, 1.5099679231643677
# j 7/17, after affine, z range: [-6.49763298034668, 5.090097427368164], z.shape=torch.Size([1, 24, 8, 8])
# j 7/17, after conv, z range: [-4.917504787445068, 6.236410140991211], z.shape=torch.Size([1, 24, 8, 8])
# j 7/17, after actnorm, z range: [-5.164772033691406, 5.373632431030273], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 8/17, scale max and min: -0.3995627760887146, 6.052854537963867
# j 8/17, after affine, z range: [-5.164772033691406, 5.373632431030273], z.shape=torch.Size([1, 24, 8, 8])
# j 8/17, after conv, z range: [-5.614197731018066, 5.492313385009766], z.shape=torch.Size([1, 24, 8, 8])
# j 8/17, after actnorm, z range: [-5.086658477783203, 4.3153767585754395], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 9/17, scale max and min: -1.1278291940689087, 3.999467134475708
# j 9/17, after affine, z range: [-5.086658477783203, 4.3153767585754395], z.shape=torch.Size([1, 24, 8, 8])
# j 9/17, after conv, z range: [-4.442193508148193, 6.131727695465088], z.shape=torch.Size([1, 24, 8, 8])
# j 9/17, after actnorm, z range: [-4.803913593292236, 4.694612503051758], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 10/17, scale max and min: -0.540873110294342, 1.504205584526062
# j 10/17, after affine, z range: [-4.803913593292236, 5.479635238647461], z.shape=torch.Size([1, 24, 8, 8])
# j 10/17, after conv, z range: [-4.765549659729004, 4.2117414474487305], z.shape=torch.Size([1, 24, 8, 8])
# j 10/17, after actnorm, z range: [-5.1101908683776855, 4.01677942276001], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 11/17, scale max and min: -0.1250816136598587, 4.053308486938477
# j 11/17, after affine, z range: [-5.1101908683776855, 4.444849967956543], z.shape=torch.Size([1, 24, 8, 8])
# j 11/17, after conv, z range: [-3.0695366859436035, 5.127523422241211], z.shape=torch.Size([1, 24, 8, 8])
# j 11/17, after actnorm, z range: [-2.939786195755005, 4.501351833343506], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 12/17, scale max and min: -0.1562403291463852, 3.2855968475341797
# j 12/17, after affine, z range: [-3.1808927059173584, 4.501351833343506], z.shape=torch.Size([1, 24, 8, 8])
# j 12/17, after conv, z range: [-3.2365405559539795, 4.585066795349121], z.shape=torch.Size([1, 24, 8, 8])
# j 12/17, after actnorm, z range: [-2.9195306301116943, 4.881579399108887], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 13/17, scale max and min: -0.6916243433952332, 1.6562271118164062
# j 13/17, after affine, z range: [-3.225045919418335, 4.881579399108887], z.shape=torch.Size([1, 24, 8, 8])
# j 13/17, after conv, z range: [-3.986814022064209, 4.435848712921143], z.shape=torch.Size([1, 24, 8, 8])
# j 13/17, after actnorm, z range: [-3.1133103370666504, 3.9149367809295654], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 14/17, scale max and min: -0.039669912308454514, 2.383389949798584
# j 14/17, after affine, z range: [-3.1133103370666504, 4.065855979919434], z.shape=torch.Size([1, 24, 8, 8])
# j 14/17, after conv, z range: [-3.349665403366089, 4.112052917480469], z.shape=torch.Size([1, 24, 8, 8])
# j 14/17, after actnorm, z range: [-3.7702465057373047, 4.267020225524902], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 15/17, scale max and min: -0.3601597845554352, 2.489744186401367
# j 15/17, after affine, z range: [-3.7702465057373047, 4.579126358032227], z.shape=torch.Size([1, 24, 8, 8])
# j 15/17, after conv, z range: [-4.488552093505859, 3.509875774383545], z.shape=torch.Size([1, 24, 8, 8])
# j 15/17, after actnorm, z range: [-4.342966079711914, 3.3662073612213135], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 16/17, scale max and min: -0.18353833258152008, 0.7727946639060974
# j 16/17, after affine, z range: [-4.342966079711914, 3.4732697010040283], z.shape=torch.Size([1, 24, 8, 8])
# j 16/17, after conv, z range: [-2.9814422130584717, 4.020692348480225], z.shape=torch.Size([1, 24, 8, 8])
# j 16/17, after actnorm, z range: [-2.6737380027770996, 4.170254707336426], z.shape=torch.Size([1, 24, 8, 8])
#
#
#
# --------------------------------
# i=2
# drawing from q[2], z_ range: [-2.970831871032715, 2.847306728363037]
# merging with q, z range: [-2.970831871032715, 4.170254707336426]
# aff.scale_map='sigmoid'
# j 1/17, scale max and min: -2.6074647903442383, 2.2109036445617676
# j 1/17, after affine, z range: [-4.661092281341553, 5.992459774017334], z.shape=torch.Size([1, 12, 16, 16])
# j 1/17, after conv, z range: [-4.755706787109375, 5.162461280822754], z.shape=torch.Size([1, 12, 16, 16])
# j 1/17, after actnorm, z range: [-4.332178592681885, 4.5897088050842285], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 2/17, scale max and min: -1.3488292694091797, 2.7229154109954834
# j 2/17, after affine, z range: [-4.332178592681885, 5.622614860534668], z.shape=torch.Size([1, 12, 16, 16])
# j 2/17, after conv, z range: [-4.518342971801758, 4.548220157623291], z.shape=torch.Size([1, 12, 16, 16])
# j 2/17, after actnorm, z range: [-4.544559955596924, 4.229950904846191], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 3/17, scale max and min: -1.0119032859802246, 2.664949417114258
# j 3/17, after affine, z range: [-4.855221748352051, 5.1919169425964355], z.shape=torch.Size([1, 12, 16, 16])
# j 3/17, after conv, z range: [-3.673912763595581, 4.958526134490967], z.shape=torch.Size([1, 12, 16, 16])
# j 3/17, after actnorm, z range: [-2.7844502925872803, 4.742234706878662], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 4/17, scale max and min: -1.3209106922149658, 7.148399353027344
# j 4/17, after affine, z range: [-3.583512544631958, 4.742234706878662], z.shape=torch.Size([1, 12, 16, 16])
# j 4/17, after conv, z range: [-3.9081976413726807, 3.998819589614868], z.shape=torch.Size([1, 12, 16, 16])
# j 4/17, after actnorm, z range: [-3.7097349166870117, 4.093420505523682], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 5/17, scale max and min: -1.3203082084655762, 2.1569161415100098
# j 5/17, after affine, z range: [-3.7097349166870117, 4.093420505523682], z.shape=torch.Size([1, 12, 16, 16])
# j 5/17, after conv, z range: [-4.361008167266846, 3.512756109237671], z.shape=torch.Size([1, 12, 16, 16])
# j 5/17, after actnorm, z range: [-4.458326816558838, 3.3609542846679688], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 6/17, scale max and min: -0.49502071738243103, 4.501401424407959
# j 6/17, after affine, z range: [-4.458326816558838, 3.367861270904541], z.shape=torch.Size([1, 12, 16, 16])
# j 6/17, after conv, z range: [-4.074942111968994, 3.890472650527954], z.shape=torch.Size([1, 12, 16, 16])
# j 6/17, after actnorm, z range: [-3.9873218536376953, 5.1003031730651855], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 7/17, scale max and min: -0.9126543402671814, 1.330665111541748
# j 7/17, after affine, z range: [-4.104852199554443, 5.1003031730651855], z.shape=torch.Size([1, 12, 16, 16])
# j 7/17, after conv, z range: [-4.533806800842285, 4.009955406188965], z.shape=torch.Size([1, 12, 16, 16])
# j 7/17, after actnorm, z range: [-4.198795795440674, 3.968453884124756], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 8/17, scale max and min: -0.9343205094337463, 1.9121688604354858
# j 8/17, after affine, z range: [-5.223221302032471, 3.968453884124756], z.shape=torch.Size([1, 12, 16, 16])
# j 8/17, after conv, z range: [-4.1635308265686035, 3.3756587505340576], z.shape=torch.Size([1, 12, 16, 16])
# j 8/17, after actnorm, z range: [-5.515056133270264, 3.2276642322540283], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 9/17, scale max and min: -1.0275095701217651, 2.2666618824005127
# j 9/17, after affine, z range: [-5.515056133270264, 3.637587070465088], z.shape=torch.Size([1, 12, 16, 16])
# j 9/17, after conv, z range: [-3.7248456478118896, 3.9187092781066895], z.shape=torch.Size([1, 12, 16, 16])
# j 9/17, after actnorm, z range: [-3.354646921157837, 3.852370023727417], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 10/17, scale max and min: -0.6828902363777161, 1.3303037881851196
# j 10/17, after affine, z range: [-3.8534927368164062, 4.256443023681641], z.shape=torch.Size([1, 12, 16, 16])
# j 10/17, after conv, z range: [-3.8661372661590576, 3.527557373046875], z.shape=torch.Size([1, 12, 16, 16])
# j 10/17, after actnorm, z range: [-4.16525936126709, 4.447300910949707], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 11/17, scale max and min: -0.4338304400444031, 1.299609661102295
# j 11/17, after affine, z range: [-4.558189868927002, 4.447300910949707], z.shape=torch.Size([1, 12, 16, 16])
# j 11/17, after conv, z range: [-2.3442530632019043, 3.9762415885925293], z.shape=torch.Size([1, 12, 16, 16])
# j 11/17, after actnorm, z range: [-2.3986198902130127, 3.9996821880340576], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 12/17, scale max and min: -0.7159359455108643, 0.4141189157962799
# j 12/17, after affine, z range: [-2.3986198902130127, 4.5115885734558105], z.shape=torch.Size([1, 12, 16, 16])
# j 12/17, after conv, z range: [-3.479856014251709, 3.6211814880371094], z.shape=torch.Size([1, 12, 16, 16])
# j 12/17, after actnorm, z range: [-2.7709052562713623, 3.899087905883789], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 13/17, scale max and min: -0.4114595353603363, 0.5809986591339111
# j 13/17, after affine, z range: [-3.068808078765869, 3.899087905883789], z.shape=torch.Size([1, 12, 16, 16])
# j 13/17, after conv, z range: [-3.781493902206421, 3.6883695125579834], z.shape=torch.Size([1, 12, 16, 16])
# j 13/17, after actnorm, z range: [-3.6866304874420166, 3.545579195022583], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 14/17, scale max and min: -0.41516509652137756, 0.876366138458252
# j 14/17, after affine, z range: [-3.72145938873291, 3.8836748600006104], z.shape=torch.Size([1, 12, 16, 16])
# j 14/17, after conv, z range: [-3.2580723762512207, 3.0101747512817383], z.shape=torch.Size([1, 12, 16, 16])
# j 14/17, after actnorm, z range: [-3.2736008167266846, 3.2247538566589355], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 15/17, scale max and min: -0.1948787420988083, 0.6112303733825684
# j 15/17, after affine, z range: [-3.646076202392578, 3.691608190536499], z.shape=torch.Size([1, 12, 16, 16])
# j 15/17, after conv, z range: [-2.9517273902893066, 3.149661064147949], z.shape=torch.Size([1, 12, 16, 16])
# j 15/17, after actnorm, z range: [-2.754739999771118, 2.561485528945923], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 16/17, scale max and min: -0.18730007112026215, 0.23082028329372406
# j 16/17, after affine, z range: [-2.754739999771118, 2.8765246868133545], z.shape=torch.Size([1, 12, 16, 16])
# j 16/17, after conv, z range: [-1.8954684734344482, 2.607517719268799], z.shape=torch.Size([1, 12, 16, 16])
# j 16/17, after actnorm, z range: [-0.03278982639312744, 0.9826522469520569], z.shape=torch.Size([1, 12, 16, 16])

# %% [markdown]
# After training on rgb 0-1 data with noise, sampling works as it should. Values of z don't jump to infinity

# %%
img = img.cpu().numpy()
img = np.transpose(img[0], (1,2,0))
plt.imshow(img, vmin=0.0, vmax=1.0)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.032789826..0.98265225].

# %% [markdown]
# ### 2.1) Convertingg

# %%
img = dataset[np.random.randint(0, len(dataset))][0]

with torch.no_grad():
    z, _ = model2.inverse_and_log_det(img[None].to(device))
    res_img, _ = model2.forward_and_log_det(z)

img = img.numpy()
res_img = res_img[0].cpu().numpy()

print(np.abs(res_img - img).max())
plt.imshow(np.transpose(img, (1,2,0)), vmin=0.0, vmax=1.0)
plt.show()
plt.imshow(np.transpose(res_img, (1,2,0)), vmin=0.0, vmax=1.0)
plt.show()
# Out:
# 1.0728836e-06

# %% [markdown]
# Converting also works.

# %% [markdown]
# ## 3) training on hsv data
# Observing sampling after training on hsv data

# %% [markdown]
# Below are two custom functions for converting between RGB and HSV color spaces.
#
# While libraries like OpenCV and Pillow provide built-in functions for these conversions, they operate on 8-bit integers (values in the range 0–255) for both input and output. This can lead to a loss of information during the conversion process. Specifically, when you convert RGB to HSV and then back to RGB using these libraries, some pixel values in the resulting RGB image can differ from the original by as much as 5 or 6 units due to rounding errors and limited precision.
#
# To address this issue, I implemented my own rgb_to_hsv and hsv_to_rgb functions. These functions work with the float64 data type, ensuring higher precision and minimizing loss of information during the conversions.

# %%
def rgb_to_hsv(rgb_array: np.ndarray) -> np.ndarray:
    """Converts image from rgb to hsv. The function expects input array to be of shape (H,W,3), of
    dtype np.float64 with values in range (0.0, 1.0). The output array is of shape (3,H,W) of dtype
    np.float64 and values in range (0.0, 1.0)."""

    maxc = np.max(rgb_array, axis=2)
    minc = np.min(rgb_array, axis=2)
    v = maxc
    rangec = maxc - minc
    vgr0 = maxc > 0.0
    rgr0 = rangec > 0.0
    s = np.zeros_like(v)
    s[vgr0] = rangec[vgr0] / maxc[vgr0]

    h = np.zeros_like(maxc)
    r, g, b = rgb_array[..., 0], rgb_array[..., 1], rgb_array[..., 2]
    ind = (r == maxc) & rgr0
    h[ind] = ((g[ind] - b[ind]) / rangec[ind]) % 6.0
    ind = (g == maxc) & rgr0
    h[ind] = 2.0 + ((b[ind] - r[ind]) / rangec[ind])
    ind = (b == maxc) & rgr0
    h[ind] = 4.0 + ((r[ind] - g[ind]) / rangec[ind])

    h = h / 6.0
    return np.stack([h, s, v])


def hsv_to_rgb(hsv_array: np.ndarray) -> np.ndarray:
    """Converts image from hsv to rgb. The function expects input array to be of shape (3,H,W),
    of dtype np.float64 with values in range (0.0, 1.0). The output array is of shape (H,W,3) of
    dtype np.float64 and values in range (0.0, 1.0)."""

    h, s, v = hsv_array[0], hsv_array[1], hsv_array[2]
    i = np.floor(h * 6.0)
    f = h * 6.0 - i
    i = i.astype(int)

    p = v * (1.0 - s)
    q = v * (1.0 - s * f)
    t = v * (1.0 - s * (1.0 - f))

    r, g, b = np.zeros_like(h), np.zeros_like(h), np.zeros_like(h)

    ind = i == 0
    r[ind] = v[ind]
    g[ind] = t[ind]
    b[ind] = p[ind]

    ind = i == 1
    r[ind] = q[ind]
    g[ind] = v[ind]
    b[ind] = p[ind]

    ind = i == 2
    r[ind] = p[ind]
    g[ind] = v[ind]
    b[ind] = t[ind]

    ind = i == 3
    r[ind] = p[ind]
    g[ind] = q[ind]
    b[ind] = v[ind]

    ind = i == 4
    r[ind] = t[ind]
    g[ind] = p[ind]
    b[ind] = v[ind]

    ind = i == 5
    r[ind] = v[ind]
    g[ind] = p[ind]
    b[ind] = q[ind]

    return np.stack([r, g, b], axis=-1)

# %%
def pil_to_hsv_tensor(img: PIL.Image) -> torch.Tensor:
    img = np.array(img)
    img = img.astype(np.float32) + np.random.rand(*img.shape).astype(np.float32)
    img = rgb_to_hsv(img / 256.0)
    img = torch.tensor(img)
    return img

# %%
dataset = ImageFolder(TRAINVAL_DIR, transform=pil_to_hsv_tensor)
img = dataset[np.random.randint(0, len(dataset))][0]
img.min().item(), img.max().item()
# Out:
# (0.0018943429458886385, 0.9998643398284912)

# %%
dataset = ImageFolder(TRAINVAL_DIR, transform=pil_to_hsv_tensor)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=8, shuffle=True)

model3 = get_glow_model()
model3 = model3.to(device)
optimizer = torch.optim.Adamax(model3.parameters(), lr=1e-3, weight_decay=1e-5)

EPOCH = 4
loss_hist = []

for epoch in range(EPOCH):
    print(f'epoch {epoch+1} /{EPOCH}')
    for x,y in tqdm(train_loader):
        optimizer.zero_grad()
        loss = model3.forward_kld(x.to(device), y.to(device))
        if torch.isnan(loss) or torch.isinf(loss):
            print(f'loss is bad: {loss}')
            break
        else:
            loss.backward()
            optimizer.step()
        loss_hist = np.append(loss_hist, loss.detach().to('cpu').numpy())
# Out:
# epoch 1 /4
# 100%|██████████| 267/267 [00:18<00:00, 14.55it/s]
# epoch 2 /4
# 100%|██████████| 267/267 [00:19<00:00, 13.69it/s]
# epoch 3 /4
# 100%|██████████| 267/267 [00:19<00:00, 13.93it/s]
# epoch 4 /4
# 100%|██████████| 267/267 [00:18<00:00, 14.10it/s]

# %%
plt.plot(loss_hist)
plt.show()

# %% [markdown]
# ### 3.1) Sampling

# %%
with torch.no_grad():
    img = sample(model3)
# Out:
# --------------------------------
# i=0
# drawing from q[0], z_ range: [-2.9691379070281982, 2.976440668106079]
# aff.scale_map='sigmoid'
# j 1/17, scale max and min: -0.641609251499176, 0.15095637738704681
# j 1/17, after affine, z range: [-3.4190731048583984, 3.1257824897766113], z.shape=torch.Size([1, 48, 4, 4])
# j 1/17, after conv, z range: [-3.2815957069396973, 3.1206717491149902], z.shape=torch.Size([1, 48, 4, 4])
# j 1/17, after actnorm, z range: [-3.2901835441589355, 3.014427900314331], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 2/17, scale max and min: -0.4962654113769531, 0.3141653537750244
# j 2/17, after affine, z range: [-3.2901835441589355, 3.076526641845703], z.shape=torch.Size([1, 48, 4, 4])
# j 2/17, after conv, z range: [-2.817943811416626, 3.1131675243377686], z.shape=torch.Size([1, 48, 4, 4])
# j 2/17, after actnorm, z range: [-2.6695523262023926, 3.4492456912994385], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 3/17, scale max and min: -0.6241989135742188, 0.20189526677131653
# j 3/17, after affine, z range: [-2.9236056804656982, 3.4492456912994385], z.shape=torch.Size([1, 48, 4, 4])
# j 3/17, after conv, z range: [-3.630208969116211, 3.514763355255127], z.shape=torch.Size([1, 48, 4, 4])
# j 3/17, after actnorm, z range: [-3.0578439235687256, 3.722998857498169], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 4/17, scale max and min: -0.7205468416213989, 0.5135142803192139
# j 4/17, after affine, z range: [-3.3133254051208496, 3.722998857498169], z.shape=torch.Size([1, 48, 4, 4])
# j 4/17, after conv, z range: [-3.797013521194458, 3.3892710208892822], z.shape=torch.Size([1, 48, 4, 4])
# j 4/17, after actnorm, z range: [-3.926179885864258, 3.3932230472564697], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 5/17, scale max and min: -0.4996339678764343, 0.11834716796875
# j 5/17, after affine, z range: [-3.926179885864258, 3.3932230472564697], z.shape=torch.Size([1, 48, 4, 4])
# j 5/17, after conv, z range: [-3.8152804374694824, 4.865434169769287], z.shape=torch.Size([1, 48, 4, 4])
# j 5/17, after actnorm, z range: [-3.5671586990356445, 4.123392581939697], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 6/17, scale max and min: -0.535398006439209, 0.4738772213459015
# j 6/17, after affine, z range: [-3.5671586990356445, 4.585726261138916], z.shape=torch.Size([1, 48, 4, 4])
# j 6/17, after conv, z range: [-3.7392542362213135, 3.6655545234680176], z.shape=torch.Size([1, 48, 4, 4])
# j 6/17, after actnorm, z range: [-3.5209643840789795, 3.7887396812438965], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 7/17, scale max and min: -0.6442081332206726, 0.1703510284423828
# j 7/17, after affine, z range: [-3.782275438308716, 3.7887396812438965], z.shape=torch.Size([1, 48, 4, 4])
# j 7/17, after conv, z range: [-3.7004294395446777, 3.411701202392578], z.shape=torch.Size([1, 48, 4, 4])
# j 7/17, after actnorm, z range: [-3.528451919555664, 3.3103716373443604], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 8/17, scale max and min: -0.4499324858188629, 0.5256068110466003
# j 8/17, after affine, z range: [-3.528451919555664, 3.3103716373443604], z.shape=torch.Size([1, 48, 4, 4])
# j 8/17, after conv, z range: [-3.1720738410949707, 3.0622761249542236], z.shape=torch.Size([1, 48, 4, 4])
# j 8/17, after actnorm, z range: [-3.1692605018615723, 2.9989185333251953], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 9/17, scale max and min: -0.5714724659919739, 0.6182624697685242
# j 9/17, after affine, z range: [-3.1692605018615723, 2.9989185333251953], z.shape=torch.Size([1, 48, 4, 4])
# j 9/17, after conv, z range: [-5.251769542694092, 2.904104471206665], z.shape=torch.Size([1, 48, 4, 4])
# j 9/17, after actnorm, z range: [-4.846908092498779, 3.0902280807495117], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 10/17, scale max and min: -0.479072242975235, 0.43927502632141113
# j 10/17, after affine, z range: [-5.555634021759033, 3.0902280807495117], z.shape=torch.Size([1, 48, 4, 4])
# j 10/17, after conv, z range: [-4.279505729675293, 3.81959867477417], z.shape=torch.Size([1, 48, 4, 4])
# j 10/17, after actnorm, z range: [-3.50947642326355, 3.4101898670196533], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 11/17, scale max and min: -0.43459075689315796, 0.3629871904850006
# j 11/17, after affine, z range: [-4.057853698730469, 3.5785553455352783], z.shape=torch.Size([1, 48, 4, 4])
# j 11/17, after conv, z range: [-3.57533597946167, 4.1922607421875], z.shape=torch.Size([1, 48, 4, 4])
# j 11/17, after actnorm, z range: [-3.464775800704956, 3.8482682704925537], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 12/17, scale max and min: -0.23429466784000397, 0.35869768261909485
# j 12/17, after affine, z range: [-3.464775800704956, 3.8482682704925537], z.shape=torch.Size([1, 48, 4, 4])
# j 12/17, after conv, z range: [-3.1667840480804443, 3.8417787551879883], z.shape=torch.Size([1, 48, 4, 4])
# j 12/17, after actnorm, z range: [-3.069403648376465, 3.1289567947387695], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 13/17, scale max and min: -0.3858078420162201, 0.37282803654670715
# j 13/17, after affine, z range: [-3.283883810043335, 3.2748963832855225], z.shape=torch.Size([1, 48, 4, 4])
# j 13/17, after conv, z range: [-4.589607238769531, 3.413278579711914], z.shape=torch.Size([1, 48, 4, 4])
# j 13/17, after actnorm, z range: [-3.7628700733184814, 3.0804038047790527], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 14/17, scale max and min: -0.40600258111953735, 0.3008383512496948
# j 14/17, after affine, z range: [-4.355074405670166, 3.4964513778686523], z.shape=torch.Size([1, 48, 4, 4])
# j 14/17, after conv, z range: [-4.320611953735352, 4.33863639831543], z.shape=torch.Size([1, 48, 4, 4])
# j 14/17, after actnorm, z range: [-4.31459903717041, 3.4392354488372803], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 15/17, scale max and min: -0.22738142311573029, 0.20778603851795197
# j 15/17, after affine, z range: [-4.31459903717041, 3.993342161178589], z.shape=torch.Size([1, 48, 4, 4])
# j 15/17, after conv, z range: [-3.295492172241211, 4.00692081451416], z.shape=torch.Size([1, 48, 4, 4])
# j 15/17, after actnorm, z range: [-4.070770740509033, 3.5318069458007812], z.shape=torch.Size([1, 48, 4, 4])
# aff.scale_map='sigmoid'
# j 16/17, scale max and min: -0.3441430926322937, 0.30863258242607117
# j 16/17, after affine, z range: [-4.070770740509033, 3.5318069458007812], z.shape=torch.Size([1, 48, 4, 4])
# j 16/17, after conv, z range: [-3.9000895023345947, 4.5699357986450195], z.shape=torch.Size([1, 48, 4, 4])
# j 16/17, after actnorm, z range: [-3.487149477005005, 4.741960525512695], z.shape=torch.Size([1, 48, 4, 4])
#
#
#
# --------------------------------
# i=1
# drawing from q[1], z_ range: [-3.8162283897399902, 3.530292272567749]
# merging with q, z range: [-3.8162283897399902, 4.741960525512695]
# aff.scale_map='sigmoid'
# j 1/17, scale max and min: -1.7564823627471924, -0.08943015336990356
# j 1/17, after affine, z range: [-5.281371593475342, 4.741960525512695], z.shape=torch.Size([1, 24, 8, 8])
# j 1/17, after conv, z range: [-4.130514621734619, 4.649686336517334], z.shape=torch.Size([1, 24, 8, 8])
# j 1/17, after actnorm, z range: [-4.4729132652282715, 3.9394052028656006], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 2/17, scale max and min: -1.2859519720077515, 0.9576519131660461
# j 2/17, after affine, z range: [-4.4729132652282715, 4.425722122192383], z.shape=torch.Size([1, 24, 8, 8])
# j 2/17, after conv, z range: [-4.1091532707214355, 4.428001403808594], z.shape=torch.Size([1, 24, 8, 8])
# j 2/17, after actnorm, z range: [-4.269527912139893, 4.416323184967041], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 3/17, scale max and min: -1.5557457208633423, 0.2855844497680664
# j 3/17, after affine, z range: [-4.75828742980957, 5.6852850914001465], z.shape=torch.Size([1, 24, 8, 8])
# j 3/17, after conv, z range: [-4.935037612915039, 5.366882801055908], z.shape=torch.Size([1, 24, 8, 8])
# j 3/17, after actnorm, z range: [-4.461536407470703, 5.357476234436035], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 4/17, scale max and min: -1.2377758026123047, 0.5704449415206909
# j 4/17, after affine, z range: [-5.456522464752197, 5.4764909744262695], z.shape=torch.Size([1, 24, 8, 8])
# j 4/17, after conv, z range: [-5.07975435256958, 4.9670209884643555], z.shape=torch.Size([1, 24, 8, 8])
# j 4/17, after actnorm, z range: [-5.132476329803467, 4.544432163238525], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 5/17, scale max and min: -1.5883103609085083, 0.9502699971199036
# j 5/17, after affine, z range: [-5.158438682556152, 5.987598896026611], z.shape=torch.Size([1, 24, 8, 8])
# j 5/17, after conv, z range: [-5.617033004760742, 5.250814437866211], z.shape=torch.Size([1, 24, 8, 8])
# j 5/17, after actnorm, z range: [-4.7288618087768555, 5.290040969848633], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 6/17, scale max and min: -1.5178933143615723, 0.3202816843986511
# j 6/17, after affine, z range: [-4.7288618087768555, 5.643899917602539], z.shape=torch.Size([1, 24, 8, 8])
# j 6/17, after conv, z range: [-6.129239082336426, 4.83455753326416], z.shape=torch.Size([1, 24, 8, 8])
# j 6/17, after actnorm, z range: [-6.188350677490234, 4.469869613647461], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 7/17, scale max and min: -1.053816795349121, 0.26592230796813965
# j 7/17, after affine, z range: [-6.188350677490234, 5.667178630828857], z.shape=torch.Size([1, 24, 8, 8])
# j 7/17, after conv, z range: [-5.519000053405762, 4.443995475769043], z.shape=torch.Size([1, 24, 8, 8])
# j 7/17, after actnorm, z range: [-5.048015117645264, 4.302346229553223], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 8/17, scale max and min: -0.7931606769561768, 1.1695398092269897
# j 8/17, after affine, z range: [-5.2003092765808105, 5.0366973876953125], z.shape=torch.Size([1, 24, 8, 8])
# j 8/17, after conv, z range: [-5.011072635650635, 6.076226234436035], z.shape=torch.Size([1, 24, 8, 8])
# j 8/17, after actnorm, z range: [-4.664407253265381, 5.641537189483643], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 9/17, scale max and min: -1.631465196609497, 0.6948118209838867
# j 9/17, after affine, z range: [-5.7755842208862305, 5.641537189483643], z.shape=torch.Size([1, 24, 8, 8])
# j 9/17, after conv, z range: [-5.279906272888184, 5.89012336730957], z.shape=torch.Size([1, 24, 8, 8])
# j 9/17, after actnorm, z range: [-5.319539546966553, 5.44710636138916], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 10/17, scale max and min: -1.09836745262146, 0.5310416221618652
# j 10/17, after affine, z range: [-5.319539546966553, 6.164306640625], z.shape=torch.Size([1, 24, 8, 8])
# j 10/17, after conv, z range: [-6.270288944244385, 5.297729015350342], z.shape=torch.Size([1, 24, 8, 8])
# j 10/17, after actnorm, z range: [-6.083564758300781, 4.487107276916504], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 11/17, scale max and min: -0.7964738607406616, 0.5356667637825012
# j 11/17, after affine, z range: [-6.083564758300781, 5.073133945465088], z.shape=torch.Size([1, 24, 8, 8])
# j 11/17, after conv, z range: [-7.258982181549072, 5.633068561553955], z.shape=torch.Size([1, 24, 8, 8])
# j 11/17, after actnorm, z range: [-5.655360698699951, 5.4819746017456055], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 12/17, scale max and min: -1.0156463384628296, 0.31255635619163513
# j 12/17, after affine, z range: [-7.045027256011963, 5.4819746017456055], z.shape=torch.Size([1, 24, 8, 8])
# j 12/17, after conv, z range: [-4.961266040802002, 5.466037273406982], z.shape=torch.Size([1, 24, 8, 8])
# j 12/17, after actnorm, z range: [-5.1827473640441895, 5.4261932373046875], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 13/17, scale max and min: -0.7673061490058899, 0.6290165185928345
# j 13/17, after affine, z range: [-5.375984191894531, 5.4261932373046875], z.shape=torch.Size([1, 24, 8, 8])
# j 13/17, after conv, z range: [-6.254466533660889, 5.882055759429932], z.shape=torch.Size([1, 24, 8, 8])
# j 13/17, after actnorm, z range: [-5.200083255767822, 5.715557098388672], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 14/17, scale max and min: -0.8082892298698425, 0.9246081709861755
# j 14/17, after affine, z range: [-6.18427848815918, 6.448795318603516], z.shape=torch.Size([1, 24, 8, 8])
# j 14/17, after conv, z range: [-5.436401844024658, 6.104755878448486], z.shape=torch.Size([1, 24, 8, 8])
# j 14/17, after actnorm, z range: [-5.700471878051758, 5.212559700012207], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 15/17, scale max and min: -0.8179629445075989, 0.1526021808385849
# j 15/17, after affine, z range: [-5.700471878051758, 5.212559700012207], z.shape=torch.Size([1, 24, 8, 8])
# j 15/17, after conv, z range: [-7.007786750793457, 4.345322132110596], z.shape=torch.Size([1, 24, 8, 8])
# j 15/17, after actnorm, z range: [-5.285210132598877, 4.017385959625244], z.shape=torch.Size([1, 24, 8, 8])
# aff.scale_map='sigmoid'
# j 16/17, scale max and min: -0.3456927239894867, 0.1979939043521881
# j 16/17, after affine, z range: [-5.852694034576416, 4.250888824462891], z.shape=torch.Size([1, 24, 8, 8])
# j 16/17, after conv, z range: [-3.302520990371704, 5.988079071044922], z.shape=torch.Size([1, 24, 8, 8])
# j 16/17, after actnorm, z range: [-3.76731538772583, 5.5787458419799805], z.shape=torch.Size([1, 24, 8, 8])
#
#
#
# --------------------------------
# i=2
# drawing from q[2], z_ range: [-3.0080204010009766, 2.8585267066955566]
# merging with q, z range: [-3.76731538772583, 5.5787458419799805]
# aff.scale_map='sigmoid'
# j 1/17, scale max and min: -3.5526907444000244, -0.139639750123024
# j 1/17, after affine, z range: [-8.244304656982422, 6.668860912322998], z.shape=torch.Size([1, 12, 16, 16])
# j 1/17, after conv, z range: [-6.597096920013428, 6.005180358886719], z.shape=torch.Size([1, 12, 16, 16])
# j 1/17, after actnorm, z range: [-6.6916351318359375, 5.693239688873291], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 2/17, scale max and min: -4.751694679260254, 1.9950916767120361
# j 2/17, after affine, z range: [-14.342036247253418, 26.43279266357422], z.shape=torch.Size([1, 12, 16, 16])
# j 2/17, after conv, z range: [-13.646668434143066, 14.000114440917969], z.shape=torch.Size([1, 12, 16, 16])
# j 2/17, after actnorm, z range: [-12.072689056396484, 11.566401481628418], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 3/17, scale max and min: -5.641552448272705, 4.063382625579834
# j 3/17, after affine, z range: [-113.81312561035156, 280.960693359375], z.shape=torch.Size([1, 12, 16, 16])
# j 3/17, after conv, z range: [-171.7736053466797, 182.33447265625], z.shape=torch.Size([1, 12, 16, 16])
# j 3/17, after actnorm, z range: [-141.85003662109375, 156.1533660888672], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 4/17, scale max and min: -45.92080307006836, 37.626197814941406
# j 4/17, after affine, z range: [-1.684193138249235e+21, 5.467557620518748e+17], z.shape=torch.Size([1, 12, 16, 16])
# j 4/17, after conv, z range: [-7.571146996872989e+20, 8.143441215833653e+20], z.shape=torch.Size([1, 12, 16, 16])
# j 4/17, after actnorm, z range: [-6.930277733023749e+20, 7.368209871851582e+20], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 5/17, scale max and min: -1.8392795875985746e+20, 9.743740983564881e+19
# j 5/17, after affine, z range: [-inf, inf], z.shape=torch.Size([1, 12, 16, 16])
# j 5/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 5/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 6/17, scale max and min: nan, nan
# j 6/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 6/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 6/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 7/17, scale max and min: nan, nan
# j 7/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 7/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 7/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 8/17, scale max and min: nan, nan
# j 8/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 8/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 8/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 9/17, scale max and min: nan, nan
# j 9/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 9/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 9/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 10/17, scale max and min: nan, nan
# j 10/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 10/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 10/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 11/17, scale max and min: nan, nan
# j 11/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 11/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 11/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 12/17, scale max and min: nan, nan
# j 12/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 12/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 12/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 13/17, scale max and min: nan, nan
# j 13/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 13/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 13/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 14/17, scale max and min: nan, nan
# j 14/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 14/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 14/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 15/17, scale max and min: nan, nan
# j 15/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 15/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 15/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# aff.scale_map='sigmoid'
# j 16/17, scale max and min: nan, nan
# j 16/17, after affine, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 16/17, after conv, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])
# j 16/17, after actnorm, z range: [nan, nan], z.shape=torch.Size([1, 12, 16, 16])

# %% [markdown]
# # After training on hsv data, sampling doesn't work anymore. Values jump to infiity!

# %%
img = dataset[np.random.randint(0, len(dataset))][0]

with torch.no_grad():
    z, _ = model3.inverse_and_log_det(img[None].to(device))
    res_img, _ = model3.forward_and_log_det(z)

img = hsv_to_rgb(img.numpy())
res_img = hsv_to_rgb(res_img[0].cpu().numpy())

print(np.abs(res_img - img).max())
plt.imshow(img, vmin=0.0, vmax=1.0)
plt.show()
plt.imshow(res_img, vmin=0.0, vmax=1.0)
plt.show()
# Out:
# 3.5241246e-06

# %% [markdown]
# However, converting to latent space and back still works.
